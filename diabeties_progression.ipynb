# %% [markdown]
# <b>PREDICTING DIABETES PROGRESSION USING DIABETES DATASET AND RIDGE REGRESSION <b/>

# %%
# install scikit-learn if not already installed
# !pip install scikit-learn
# !pip install numpy
# !pip install matplotlib

# %%
# import required libararies
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import  mean_absolute_error

# %%
# load dataset
data = load_diabetes()
x,y = data.data , data.target

# %%
# split dataset
X_train , X_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# train model
model = Ridge(alpha=1.0)
model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
# predict and avaluate
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)

# %%
print(f"Diabetes Progression Prediction MAE: {mae:.2f}")
# Out:
# Diabetes Progression Prediction MAE: 46.14

# %% [markdown]
# <b>VISUALIZATIONS FOR DATA<b/>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Scatter plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='green')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='dashed')
plt.xlabel("Actual Diabetes Progression")
plt.ylabel("Predicted Diabetes Progression")
plt.title("Actual vs. Predicted (Diabetes Progression)")
plt.show()
